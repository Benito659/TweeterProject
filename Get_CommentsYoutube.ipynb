# %%
from googleapiclient.discovery import build

#credentials https://console.developers.google.com/

api_key ="AIzaSyDnyrf-muwJ5OuKzoFaVD_PmLPDMH5Iz8w"
video_id= "aWzlQ2N6qqg"

resource = build('youtube', 'v3', developerKey=api_key)

# %%
request = resource.commentThreads().list(
                            part="snippet",
                            videoId=video_id,
                            maxResults= 10000,   #get 20 comments
                            order="relevance")  #top comments.

response =request.execute()
 
items = response["items"][:10000]
print("------------------------------------------------------------------------------------------------------")
for item in items:
    item_info = item["snippet"]
    
    #the top level comment can have sub reply comments
    topLevelComment = item_info["topLevelComment"]
    comment_info = topLevelComment["snippet"]
    
    print("Comment By:", comment_info["authorDisplayName"])
    print("Comment Text:" ,comment_info["textDisplay"])
    print("Likes on Comment:", comment_info["likeCount"])
    print("Comment Date: ", comment_info['publishedAt'])
    print("================================\n")
# Out:
# ------------------------------------------------------------------------------------------------------
# Comment By: Gold Roger
# Comment Text: Props to the cameraman for going to different dimensions.
# Likes on Comment: 33118
# Comment Date:  2022-02-14T10:57:38Z
# ...
#
# Comment By: Super Drifter-17
# Comment Text: anyone else love that this trailer pictured a variant of strange as the main villain but what we got was entirely different
# Likes on Comment: 1823
# Comment Date:  2022-05-09T07:34:55Z
# ...
#
# Comment By: Jahoob_the_Great
# Comment Text: I don’t care what people say this is one of the best MCU films. You can tell Rami had full control over the production.
# Likes on Comment: 258
# Comment Date:  2022-05-17T01:17:58Z
# ...
#
# Comment By: Captain Sprinkles
# ...

# %%
request = resource.videos().list(part="statistics, contentDetails, snippet", id=video_id)
response=request.execute()

items=response["items"][:1000]
print(response)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'vprmSyfzdnld13u6p5ae_bwhw6w', 'items': [{'kind': 'youtube#video', 'etag': 'mCMRMT7PcdkVCKmSKt_iKuH4UH0', 'id': 'aWzlQ2N6qqg', 'snippet': {'publishedAt': '2022-02-13T23:12:44Z', 'channelId': 'UCvC4D8onUfXzvjTOM-dBfEA', 'title': "Marvel Studios' Doctor Strange in the Multiverse of Madness | Official Trailer", 'description': "Enter a new dimension of Strange. Watch the official trailer for Marvel Studios' Doctor Strange in the Multiverse of Madness. Only in theaters May 6.\n\nIn Marvel Studios’ “Doctor Strange in the Multiverse of Madness,” the MCU unlocks the Multiverse and pushes its boundaries further than ever before. Journey into the unknown with Doctor Strange, who, with the help of mystical allies both old and new, traverses the mind-bending and dangerous alternate realities of the Multiverse to confront a mysterious new adversary.\n\n“Doctor Strange in the Multiverse of Madness” stars Benedict Cumberbatch, Chiwetel Ejiofor, Elizabet
# ...
